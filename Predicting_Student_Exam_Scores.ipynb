# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshanBathini/Predicting-Student-Exam-Scores/blob/main/Predicting_Student_Exam_Scores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df =pd.read_csv("/content/student_habits_performance.csv")

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum().sum()
# Out:
# np.int64(91)

# %%
df = df.dropna()

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# ...

# %%
df.describe(include="object").columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
categorical_cols =["gender","part_time_job","diet_quality","parental_education_level","internet_quality"]

# %%
for col in categorical_cols:
  print(f"Value counts for {col}:")
  print(df[col].value_counts())
  print("\n")
# Out:
# Value counts for gender:
# gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
#
#
# Value counts for part_time_job:
# part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
#
#
# Value counts for diet_quality:
# diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
#
#
# Value counts for parental_education_level:
# parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
#
#
# Value counts for internet_quality:
# internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64

# %%
df.hist(bins=20, edgecolor="purple")
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
  sns.countplot(data=df, x = col)
  plt.title(f"Distribution of {col}")
  plt.xticks(rotation = 45)
  plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for feature in num_features:
  sns.scatterplot(data = df, x = feature, y ="exam_score")
  plt.title(f"{feature} vs Exam Score")
  plt.show()

# %%
for col in categorical_cols:
  sns.boxplot(data = df, x = col, y = "exam_score")
  plt.title(f"{col} vs Exam Score")
  plt.xticks(rotation=45)
  plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
features = ["study_hours_per_day", "social_media_hours", "netflix_hours", "attendance_percentage", "sleep_hours", "exercise_frequency", "mental_health_rating", "part_time_job"]

# %%
target = "exam_score"

# %%
df_model = df[features + [target]].copy()
display(df_model.head())
# Out:
#    study_hours_per_day  social_media_hours  netflix_hours  \
# 0                  0.0                 1.2            1.1
# 1                  6.9                 2.8            2.3
# 2                  1.4                 3.1            1.3
# 3                  1.0                 3.9            1.0
# 4                  5.0                 4.4            0.5
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0                   85.0          8.0                   6
# 1                   97.3          4.6                   6
# 2                   94.8          8.0                   1
# 3                   71.0          9.2                   4
# 4                   90.9          4.9                   3
#
#    mental_health_rating part_time_job  exam_score
# 0                     8            No        56.2
# 1                     8            No       100.0
# 2                     1            No        34.3
# 3                     1            No        26.8
# ...

# %%
df_model
# Out:
#      study_hours_per_day  social_media_hours  netflix_hours  \
# 0                    0.0                 1.2            1.1
# 1                    6.9                 2.8            2.3
# 2                    1.4                 3.1            1.3
# 3                    1.0                 3.9            1.0
# 4                    5.0                 4.4            0.5
# ..                   ...                 ...            ...
# 995                  2.6                 0.5            1.6
# 996                  2.9                 1.0            2.4
# 997                  3.0                 2.6            1.3
# 998                  5.4                 4.1            1.1
# 999                  4.3                 2.9            1.9
#
#      attendance_percentage  sleep_hours  exercise_frequency  \
# 0                     85.0          8.0                   6
# 1                     97.3          4.6                   6
# 2                     94.8          8.0                   1
# ...

# %%
le = LabelEncoder()

# %%
df_model["part_time_job"] = le.fit_transform(df_model["part_time_job"])
display(df_model.head())
# Out:
#    study_hours_per_day  social_media_hours  netflix_hours  \
# 0                  0.0                 1.2            1.1
# 1                  6.9                 2.8            2.3
# 2                  1.4                 3.1            1.3
# 3                  1.0                 3.9            1.0
# 4                  5.0                 4.4            0.5
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0                   85.0          8.0                   6
# 1                   97.3          4.6                   6
# 2                   94.8          8.0                   1
# 3                   71.0          9.2                   4
# 4                   90.9          4.9                   3
#
#    mental_health_rating  part_time_job  exam_score
# 0                     8              0        56.2
# 1                     8              0       100.0
# 2                     1              0        34.3
# 3                     1              0        26.8
# ...

# %%
df_model
# Out:
#      study_hours_per_day  social_media_hours  netflix_hours  \
# 0                    0.0                 1.2            1.1
# 1                    6.9                 2.8            2.3
# 2                    1.4                 3.1            1.3
# 3                    1.0                 3.9            1.0
# 4                    5.0                 4.4            0.5
# ..                   ...                 ...            ...
# 995                  2.6                 0.5            1.6
# 996                  2.9                 1.0            2.4
# 997                  3.0                 2.6            1.3
# 998                  5.4                 4.1            1.1
# 999                  4.3                 2.9            1.9
#
#      attendance_percentage  sleep_hours  exercise_frequency  \
# 0                     85.0          8.0                   6
# 1                     97.3          4.6                   6
# 2                     94.8          8.0                   1
# ...

# %%
X = df_model[features]

# %%
y = df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
#      study_hours_per_day  social_media_hours  netflix_hours  \
# 88                   3.9                 2.3            2.1
# 11                   3.9                 2.4            2.5
# 684                  3.7                 2.8            3.6
# 270                  4.0                 3.2            2.3
# 960                  7.1                 1.9            1.1
#
#      attendance_percentage  sleep_hours  exercise_frequency  \
# 88                   100.0          6.1                   6
# 11                    71.7          7.9                   2
# 684                   81.8          3.6                   3
# 270                   96.6          6.0                   4
# 960                   69.3          5.6                   6
#
#      mental_health_rating  part_time_job
# 88                      4              0
# 11                      1              0
# 684                     4              0
# 270                     3              1
# ...

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models = {
    "LinearRegression": {
    "model": LinearRegression(),
    "params": {}
},
    "DecisionTree" : {
        "model" : DecisionTreeRegressor(),
        "params": {"max_depth": [3,5,10], "min_samples_split": [2,5]}
    },
    "RandomForest": {
        "model": RandomForestRegressor(),
        "params": {"n_estimators": [50,100], "max_depth": [5,10]}
    }

}

# %%
best_models = []

# %%
best_models = []

for name, config in models.items():
  print(f"Training {name}...")

  grid_search = GridSearchCV(config["model"], config["params"], cv=5, scoring="neg_mean_squared_error")
  grid_search.fit(X_train, y_train)

  y_pred = grid_search.predict(X_test)
  rmse = np.sqrt(mean_squared_error(y_test, y_pred))
  r2 = r2_score(y_test, y_pred)

  best_models.append({
      "model": name,
      "best_params": grid_search.best_params_,
      "rmse": rmse,
      "r2": r2
  })
# Out:
# Training LinearRegression...
# Training DecisionTree...
# Training RandomForest...

# %%
best_models
# Out:
# [{'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(5.470346389864339),
#   'r2': 0.8897529592739154},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 2},
#   'rmse': np.float64(7.873243636621264),
#   'r2': 0.771627046851154},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 10, 'n_estimators': 100},
#   'rmse': np.float64(5.783268926671056),
#   'r2': 0.8767791892848008}]

# %%
results_df = pd.DataFrame(best_models)

# %%
results_df
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  5.470346
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 2}  7.873244
# 2      RandomForest    {'max_depth': 10, 'n_estimators': 100}  5.634902
#
#          r2
# 0  0.889753
# 1  0.771627
# 2  0.883020

# %%
results_df.sort_values(by="rmse")
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  5.470346
# 2      RandomForest    {'max_depth': 10, 'n_estimators': 100}  5.634902
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 2}  7.873244
#
#          r2
# 0  0.889753
# 2  0.883020
# 1  0.771627

# %%
import joblib

best_row = results_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                   5.470346
# r2                     0.889753
# Name: 0, dtype: object

# %%
best_model_name = best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"]

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
final_model.predict(X_test)
# Out:
# array([ 61.971878  ,  50.93747083,  70.64885976,  70.70547523,
#         87.60626945,  64.0219137 ,  77.9355673 ,  93.43683166,
#         66.75777793,  67.73732416,  56.3051244 ,  76.74083106,
#         57.42966507,  50.04942139,  77.45120482,  76.55896934,
#         48.49256854,  90.27740385,  84.9278648 ,  64.81922658,
#         74.88076628,  98.07556548,  55.04352095,  68.05265575,
#         81.94377401,  63.61974009, 104.39261795,  76.94577553,
#         60.16961838, 103.21239798,  60.13169991,  81.73448073,
#         54.14339007,  63.89000417,  62.1047859 ,  64.94467298,
#         98.39911882,  56.01566946,  60.45869111,  74.11256426,
#         60.09205226,  84.20413738,  69.3082086 ,  69.66940914,
#         88.37739214,  71.24640895,  48.5452043 ,  99.94996038,
#         79.5755653 ,  79.67878289,  63.14444804,  47.8498603 ,
#         64.67942251,  74.02766492,  70.2151008 , 103.08509326,
#         69.08681575,  59.39155894,  80.75286254,  58.46598278,
# ...

# %%
joblib.dump(final_model, "best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(X_test)
# Out:
# array([ 61.971878  ,  50.93747083,  70.64885976,  70.70547523,
#         87.60626945,  64.0219137 ,  77.9355673 ,  93.43683166,
#         66.75777793,  67.73732416,  56.3051244 ,  76.74083106,
#         57.42966507,  50.04942139,  77.45120482,  76.55896934,
#         48.49256854,  90.27740385,  84.9278648 ,  64.81922658,
#         74.88076628,  98.07556548,  55.04352095,  68.05265575,
#         81.94377401,  63.61974009, 104.39261795,  76.94577553,
#         60.16961838, 103.21239798,  60.13169991,  81.73448073,
#         54.14339007,  63.89000417,  62.1047859 ,  64.94467298,
#         98.39911882,  56.01566946,  60.45869111,  74.11256426,
#         60.09205226,  84.20413738,  69.3082086 ,  69.66940914,
#         88.37739214,  71.24640895,  48.5452043 ,  99.94996038,
#         79.5755653 ,  79.67878289,  63.14444804,  47.8498603 ,
#         64.67942251,  74.02766492,  70.2151008 , 103.08509326,
#         69.08681575,  59.39155894,  80.75286254,  58.46598278,
# ...

# %% [markdown]
# APPInterface Section

# %%
import streamlit as st
import joblib
import warnings
warnings.filterwarnings("ignore")
import numpy as np

model = joblib.load("best_model.pkl")

st.title("Student Exam Score Prediction")


study_hours = st.slider("Study Hours per day")
attendance= st.slider("Attendance Percentage")
social_media_hours= st.slider("Social Media Hours")
netflix_hours= st.slider("Netflix Hours")
sleep_hours= st.slider("Sleep Hours")
exercise_frequency= st.slider("Exercise Frequency")
mental_health_rating = st.slider("Mental Health Rating")
part_time_job = st.selectbox("Part-Time Job", ["No", "Yes"])


ptj_encoded = 1 if part_time_job == "Yes" else 0

if st.button("Predict Exam Score"):

  input_data = np.array([[study_hours, attendance, social_media_hours, netflix_hours, sleep_hours, exercise_frequency, mental_health_rating, ptj_encoded]])
  prediction = model.predict(input_data)[0]

  prediction = max(0, min(100,prediction))


  st.success(f"predicted Exam Score: {prediction:2f}")
# Out:
# 2025-08-29 09:32:43.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-29 09:32:43.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-29 09:32:43.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-29 09:32:43.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-29 09:32:43.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-29 09:32:43.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-29 09:32:43.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
